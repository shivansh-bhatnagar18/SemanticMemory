# %% [markdown]
# Creating a basic structure of the Feature + Network Based Heirarchial Tree

# %%
class Node:
    def __init__(self, name, features=None):
        self.name = name
        self.features = features if features else {}
        self.children = []

    def add_child(self, child_node):
        self.children.append(child_node)

    def __str__(self, level=0):
        indent = " " * (level * 2)
        node_str = f"{indent}- {self.name}"
        if self.features:
            node_str += f" (Features: {self.features})"
        node_str += "\n"
        for child in self.children:
            node_str += child.__str__(level + 1)
        return node_str


root = Node("Living Organisms", {})
child1 = Node("Animals", {})
child2 = Node("Plants", {})
subchild1 = Node("Mammals", {})
subchild2 = Node("Insects", {})
subchild3 = Node("Birds", {})
subchild4 = Node("Flowers", {})
subchild5 = Node("Fruits", {})
subchild6 = Node("Trees", {})

root.add_child(child1)
root.add_child(child2)
child1.add_child(subchild1)
child1.add_child(subchild2)
child1.add_child(subchild3)
child2.add_child(subchild4)
child2.add_child(subchild5)
child2.add_child(subchild6)


print(root)
# Out:
# - Living Organisms
#   - Animals
#     - Mammals
#     - Insects
#     - Birds
#   - Plants
#     - Flowers
#     - Fruits
#     - Trees

# %% [markdown]
# Applying Natural Language Processing To Create List of Word Features
# (BAG OF WORDS MODEL)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('data.csv')
dataset
# Out:
#                                              LION  \
# 0                        "Majestic mane in males"
# 1                     "Prominent canines (fangs)"
# 2        "Distinctive roar heard from miles away"
# 3                   "Powerful and muscular build"
# 4                       "Sharp retractable claws"
# 5        "Camouflaging fur (tan with black mane)"
# 6          "Social behavior with prides (groups)"
# 7                         "Territorial instincts"
# 8      "Carnivorous diet (prey on large mammals)"
# 9                  "Primary hunters in lionesses"
#
#                                               "ROSE"  \
# 0                            "Woody perennial plant"
# 1                             "Compact growth habit"
# 2   "Usually smaller in size compared to rose bus...
# 3             "Multiple stems arising from the base"
# 4                       "Leaves with serrated edges"
# 5              "Flowers often smaller and clustered"
# 6                  "Various colors and flower types"
# 7                                "Fragrant blossoms"
# 8   "Commonly used in garden borders and landscap...
# 9                                  "Low maintenance"
#
#                                                "DOG"  \
# 0                                          "feature"
# 1                                   "Diverse Breeds"
# 2                              "Loyal Companionship"
# 3                                      "Playfulness"
# 4                                     "Intelligence"
# 5                                      "Varied Size"
# 6                  "Keen Senses (Smell and Hearing)"
# 7                              "Protective Instinct"
# 8                                   "Social Animals"
# 9   "Communication (Barking Body Language Tail Wa...
#
#                              "EAGLE"                         "BUTTERFLY"  \
# 0                  "Majestic Flight"                    "Colorful Wings"
# 1            "Sharp Beak and Talons"            "Delicate and Thin Body"
# 2                 "Excellent Vision"             "Floral Nectar Feeding"
# 3                 "Strong Predators"           "Elegant Flight Patterns"
# 4                   "Large Wingspan"          "Metamorphosis Life Cycle"
# 5   "Distinctive Plumage (Feathers)"   "Attractive Patterns and Designs"
# 6            "High Altitude Soaring"              "Antennae for Sensing"
# 7                "Territorial Birds"               "Global Distribution"
# 8                "Excellent Hunters"          "Environmental Indicators"
# 9      "Symbol of Freedom and Power"                       "Pollinators"
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
corpus = []
for i in range(0, 9):
  review = re.sub('[^a-zA-Z]', ' ', dataset['LION'][i])
  review = review.lower()
  review = review.split()
  print(review)
  ps = PorterStemmer()
  all_stopwords = stopwords.words('english')
  all_stopwords.remove('not')
  review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
  review = ' '.join(review)
  corpus.append(review)
# Out:
# ['majestic', 'mane', 'in', 'males']
# ['prominent', 'canines', 'fangs']
# ['distinctive', 'roar', 'heard', 'from', 'miles', 'away']
# ['powerful', 'and', 'muscular', 'build']
# ['sharp', 'retractable', 'claws']
# ['camouflaging', 'fur', 'tan', 'with', 'black', 'mane']
# ['social', 'behavior', 'with', 'prides', 'groups']
# ['territorial', 'instincts']
# ['carnivorous', 'diet', 'prey', 'on', 'large', 'mammals']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(corpus)
# Out:
# ['majest mane male', 'promin canin fang', 'distinct roar heard mile away', 'power muscular build', 'sharp retract claw', 'camouflag fur tan black mane', 'social behavior pride group', 'territori instinct', 'carnivor diet prey larg mammal']
